# %%
from modelscope.hub.snapshot_download import snapshot_download

# 指定模型ID和下载目录 (可选)
cache_dir = './dataset' # 指定下载保存的本地路径


# 下载模型

print(f"模型已下载到: " + snapshot_download('pretrain_t2t_mini.jsonl', cache_dir=cache_dir))
print(f"模型已下载到: " + snapshot_download('sft_t2t_mini.jsonl', cache_dir=cache_dir))
